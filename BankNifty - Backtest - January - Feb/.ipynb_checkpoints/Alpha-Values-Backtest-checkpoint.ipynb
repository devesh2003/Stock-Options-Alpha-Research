# %%
import pandas as pd
from matplotlib.pyplot import plot

# %%
options = pd.read_csv("banknifty-options-ce.csv")
prices = pd.read_csv("banknifty-prices.csv")

# %%
options["Alpha"] = (prices["Close"] - options["Strike Price"]) / options["Close"]
prices["Change"] = ((prices["Close"] - prices["Open"]) / prices["Close"])*100
# options["Alpha-Prev"] = options.Alpha.shift(1)
options["Alpha-Change"] = ((options["Alpha"] - options.Alpha.shift(1)) / options["Alpha"])*100
options["Alpha-Mean"] = (options.Alpha.shift(1)+options.Alpha.shift(2)+options.Alpha.shift(3)) / 3
options["Change"] = ((options["Open"] - options["Close"]) / options["Open"])*100

# %%
plot(options["Alpha-Change"])
# plot(options["Change"])

# %%
plot(prices["Change"])
plot(options["Change"])

# %%
# prices

# %%
options[10:]
# Out:
#        Symbol         Date       Expiry Option Type  Strike Price     Open  \
# 10  BANKNIFTY  17-Jan-2022  24-Feb-2022          CE         35000  3831.20
# 11  BANKNIFTY  18-Jan-2022  24-Feb-2022          CE         35000  3840.00
# 12  BANKNIFTY  19-Jan-2022  24-Feb-2022          CE         35000  3440.35
# 13  BANKNIFTY  20-Jan-2022  24-Feb-2022          CE         35000  3503.00
# 14  BANKNIFTY  21-Jan-2022  24-Feb-2022          CE         35000  2900.00
# 15  BANKNIFTY  24-Jan-2022  24-Feb-2022          CE         35000  3087.35
# 16  BANKNIFTY  25-Jan-2022  24-Feb-2022          CE         35000  2365.95
# 17  BANKNIFTY  27-Jan-2022  24-Feb-2022          CE         35000  2700.00
# 18  BANKNIFTY  28-Jan-2022  24-Feb-2022          CE         35000  3600.00
# 19  BANKNIFTY  31-Jan-2022  24-Feb-2022          CE         35000  3440.00
# 20  BANKNIFTY  01-Feb-2022  24-Feb-2022          CE         35000  3550.15
# 21  BANKNIFTY  02-Feb-2022  24-Feb-2022          CE         35000  4078.10
# 22  BANKNIFTY  03-Feb-2022  24-Feb-2022          CE         35000  4451.70
# 23  BANKNIFTY  04-Feb-2022  24-Feb-2022          CE         35000  4061.65
# 24  BANKNIFTY  07-Feb-2022  24-Feb-2022          CE         35000  3815.85
# 25  BANKNIFTY  08-Feb-2022  24-Feb-2022          CE         35000  3186.35
# 26  BANKNIFTY  09-Feb-2022  24-Feb-2022          CE         35000  3432.05
# 27  BANKNIFTY  10-Feb-2022  24-Feb-2022          CE         35000  3748.05
# 28  BANKNIFTY  11-Feb-2022  24-Feb-2022          CE         35000  3686.20
# 29  BANKNIFTY  14-Feb-2022  24-Feb-2022          CE         35000  2760.35
# 30  BANKNIFTY  15-Feb-2022  24-Feb-2022          CE         35000  2176.95
# 31  BANKNIFTY  16-Feb-2022  24-Feb-2022          CE         35000  3218.55
# 32  BANKNIFTY  17-Feb-2022  24-Feb-2022          CE         35000  3099.80
# 33  BANKNIFTY  18-Feb-2022  24-Feb-2022          CE         35000  2460.95
# 30           3500.63                    219.38     13500           625
# 31           1151.82                     93.07     13250          -250
# 32           1461.63                    105.38     13350           100
# 33           4167.56                    291.31     15600          2250
# 34           5622.76                    381.51     13500         -2100
# 35           4948.83                    302.58     16150          2650
# 36           3893.87                    271.37     12600         -3550
# 37        1132788.59                  13856.09     68875         56275
#
#     Underlying Value     Alpha  Alpha-Change  Alpha-Mean     Change
# 10                 -  0.859933     -3.413573    0.890144   2.380455
# 11                 -  0.861906      0.228950    0.877387   3.003906
# 12          38041.35  0.864794      0.333870    0.870376  -2.223611
# 13          37850.85  0.835279     -3.533487    0.862211   2.567799
# 14                 -  0.832743     -0.304574    0.853993  -6.598276
# 15                 -  0.749490    -11.107937    0.844272  15.833968
# 16          37706.75  0.850150     11.840250    0.805837 -34.569623
# 17                 -  0.867192      1.965201    0.810794 -27.362963
# 18                 -  0.864967     -0.257190    0.822277  13.631944
# 19                 -  0.896973      3.568203    0.860770   3.572674
# 20                 -  0.949627      5.544660    0.876378  -3.980114
# 21           39330.5  0.969877      2.087892    0.903856  -9.487261
# 22                 -  0.961227     -0.899841    0.938826   6.288609
# 23                 -  0.966967      0.593570    0.960244   3.517044
# 24                 -  0.949129     -1.879438    0.966024  17.292346
# 25                 -  0.953722      0.481662    0.959108   0.343653
# 26                 -  0.986407      3.313514    0.956606  -6.641803
# 27                 -  0.981080     -0.542968    0.963086  -9.078054
# 28                 -  0.989145      0.815300    0.973737   3.536162
# 29                 -  0.909743     -8.727912    0.985544  23.998768
# 30                 -  0.985467      7.684079    0.959989 -47.768667
# 31           37953.8  1.024114      3.773660    0.961452  10.386665
# 32                 -  0.997852     -2.631838    0.973108  18.152784
# 33                 -  0.982703     -1.541598    1.002478  -7.474756
# 34                 -  1.000559      1.784631    1.001556  -3.300171
# 35                 -  1.007840      0.722490    0.993704 -12.437288
# 36          37392.05  0.977864     -3.065536    0.997034   6.220169
# 37                 -  0.782639    -24.944478    0.995421  78.635831
#
# [28 rows x 21 columns]

# %%
threshold = 0.3
max_profit = 0
optimal_thresh = 0
while(threshold <= 2):
    net_result = 0
    threshold += 0.01
    for index,rows in options.iterrows():
        if index < 0:
            continue
        if (rows["Alpha"] / rows["Alpha-Mean"]) > threshold:
#             print("Buy!")
            try:
                result = options["Change"][index+1]
                net_result += result
            except:
                pass
    if net_result >= max_profit:
        max_profit = net_result
        optimal_thresh = threshold

print("Net profit : " + str(max_profit))
print("Optimal Threshold: " + str(optimal_thresh))
# Out:
# Net profit : 97.13509804351827
# Optimal Threshold: 0.9700000000000005

# %%
net_result = 0
for index,rows in options.iterrows():
        if index < 0:
            continue
        if (rows["Alpha"] / rows["Alpha-Mean"]) > 1:
#             print("Buy!")
            try:
                result = options["Change"][index+1]
                net_result += result
            except:
                pass
print(str(net_result))
# Out:
# 24.356720662065783
