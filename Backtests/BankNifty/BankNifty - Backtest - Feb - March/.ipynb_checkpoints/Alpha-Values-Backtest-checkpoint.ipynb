# %%
import pandas as pd
from matplotlib.pyplot import plot

# %%
options = pd.read_csv("banknifty-options.csv")
prices = pd.read_csv("banknifty-prices.csv")

# %%
options["Alpha"] = (prices["Close"] - options["Strike Price"]) / options["Close"]
prices["Change"] = ((prices["Close"] - prices["Open"]) / prices["Close"])*100
# options["Alpha-Prev"] = options.Alpha.shift(1)
options["Alpha-Change"] = ((options["Alpha"] - options.Alpha.shift(1)) / options["Alpha"])*100
options["Alpha-Mean"] = (options.Alpha.shift(1)+options.Alpha.shift(2)+options.Alpha.shift(3)) / 3
options["Change"] = ((options["Close"] - options["Open"]) / options["Close"])*100

# %%
plot(options["Alpha-Change"])
# plot(options["Change"])

# %%
plot(prices["Change"])
plot(options["Change"])

# %%
# prices

# %%
options[10:]
# Out:
#        Symbol         Date       Expiry Option Type  Strike Price    Open  \
# 10  BANKNIFTY  15-Feb-2022  31-Mar-2022          PE         30000   98.00
# 11  BANKNIFTY  16-Feb-2022  31-Mar-2022          PE         30000   45.00
# 12  BANKNIFTY  17-Feb-2022  31-Mar-2022          PE         30000   50.20
# 13  BANKNIFTY  18-Feb-2022  31-Mar-2022          PE         30000   65.00
# 14  BANKNIFTY  21-Feb-2022  31-Mar-2022          PE         30000   58.65
# 15  BANKNIFTY  22-Feb-2022  31-Mar-2022          PE         30000   68.00
# 16  BANKNIFTY  23-Feb-2022  31-Mar-2022          PE         30000   60.25
# 17  BANKNIFTY  24-Feb-2022  31-Mar-2022          PE         30000   68.00
# 18  BANKNIFTY  25-Feb-2022  31-Mar-2022          PE         30000  196.10
# 19  BANKNIFTY  28-Feb-2022  31-Mar-2022          PE         30000  125.00
# 20  BANKNIFTY  02-Mar-2022  31-Mar-2022          PE         30000  165.90
# 21  BANKNIFTY  03-Mar-2022  31-Mar-2022          PE         30000  152.00
# 22  BANKNIFTY  04-Mar-2022  31-Mar-2022          PE         30000  277.00
# 23  BANKNIFTY  07-Mar-2022  31-Mar-2022          PE         30000  318.15
# 24  BANKNIFTY  08-Mar-2022  31-Mar-2022          PE         30000  499.90
# 25  BANKNIFTY  09-Mar-2022  31-Mar-2022          PE         30000  378.00
# 26  BANKNIFTY  10-Mar-2022  31-Mar-2022          PE         30000  190.00
# 27  BANKNIFTY  11-Mar-2022  31-Mar-2022          PE         30000  150.00
# 28  BANKNIFTY  14-Mar-2022  31-Mar-2022          PE         30000  120.00
# 29  BANKNIFTY  15-Mar-2022  31-Mar-2022          PE         30000   68.00
# 30  BANKNIFTY  16-Mar-2022  31-Mar-2022          PE         30000   70.00
# 31  BANKNIFTY  17-Mar-2022  31-Mar-2022          PE         30000   29.70
# 32  BANKNIFTY  21-Mar-2022  31-Mar-2022          PE         30000   22.85
# 33  BANKNIFTY  22-Mar-2022  31-Mar-2022          PE         30000   15.00
# 34  BANKNIFTY  23-Mar-2022  31-Mar-2022          PE         30000    7.95
# 35  BANKNIFTY  24-Mar-2022  31-Mar-2022          PE         30000   29.05
# 36  BANKNIFTY  25-Mar-2022  31-Mar-2022          PE         30000    5.60
# 26                    561.56    387550        -28525           34475.6
# 27                    307.23    390675          3125                 -
# 28                    251.57    401950         11275                 -
# 29                    213.66    434750         32800                 -
# 30                     88.54    410725        -24025          35748.25
# 31                     37.97    383425        -27300                 -
# 32                     21.41    370450        -12975                 -
# 33                     13.43    359500        -10950                 -
# 34                      8.81    365750          6250                 -
# 35                     26.63    432150         66400                 -
# 36                     46.67    459450         27300                 -
# 37                     27.01    423025        -36425                 -
# 38                     10.31    387250        -35775                 -
# 39                      4.27    339850        -47400           36334.3
# 40                      1.89    315175        -24675                 -
#
#            Alpha  Alpha-Change   Alpha-Mean      Change
# 10    167.936280     42.181413   196.466839 -101.438849
# 11    158.600199     -5.886550   169.927742   10.269192
# 12    134.493750    -17.923844   141.211621   10.357143
# 13    145.717162      7.702190   153.676743  -24.640460
# 14    148.945736      2.167618   146.270370  -13.662791
# 15    123.893277    -20.221000   143.052216  -14.285714
# 16    153.840791     19.466562   139.518725  -25.390219
# 17     24.736693   -521.913336   142.226602   67.825881
# 18     66.467700     62.783890   100.823587 -102.687339
# 19     48.403276    -37.320664    81.681728    2.496100
# 20     27.286948    -77.386187    46.535890   15.744033
# 21     25.072515     -8.832111    47.385975   22.920892
# 22     19.572824    -28.098608    33.587580  -23.001776
# 23      6.311133   -210.131697    23.977429   30.069238
# 24      8.252156     23.521401    16.985491  -30.624510
# 25     17.602999     53.120739    11.378704  -74.394464
# 26     33.944634     48.142028    10.722096  -44.103148
# 27     39.191810     13.388451    19.933263  -29.310345
# 28     75.996423     48.429402    30.246481  -71.673820
# 29     61.589822    -23.391205    49.710956   16.615573
# 30    156.841746     60.731232    58.926019  -90.995907
# 31    320.625935     51.082639    98.142664  -48.129676
# 32    412.226027     22.220842   179.685835  -56.506849
# 33    733.936416     43.833550   296.564570  -73.410405
# 34    661.005376    -11.033350   488.929460   14.516129
# 35    986.982143     33.027626   602.389273 -418.750000
# 36   1229.568182     19.729369   793.974645  -27.272727
# 37   2076.545455     40.787803   959.185234  -41.818182
# 38   3439.647059     39.629113  1431.031926    2.941176
# 39   7917.875000     56.558457  2248.586898 -137.500000
# 40  42490.666667     81.365614  4478.022504 -566.666667
#
# [31 rows x 21 columns]

# %%
threshold = 0.3
max_profit = 0
optimal_thresh = 0
while(threshold <= 2):
    net_result = 0
    threshold += 0.01
    for index,rows in options.iterrows():
        if index < 20:
            continue
        if (rows["Alpha"] / rows["Alpha-Mean"]) > threshold:
#             print("Buy!")
            try:
                result = options["Change"][index+1]
                net_result += result
            except:
                pass
    if net_result >= max_profit:
        max_profit = net_result
        optimal_thresh = threshold

print("Net profit : " + str(max_profit))
print("Optimal Threshold: " + str(optimal_thresh))
# Out:
# Net profit : 0
# Optimal Threshold: 0

# %%
net_result = 0
for index,rows in options.iterrows():
        if index < 20:
            continue
        if (rows["Alpha"] / rows["Alpha-Mean"]) > 1.08:
#             print("Buy!")
            try:
                result = options["Change"][index+1]
                net_result += result
            except:
                pass
print(str(net_result))
# Out:
# -1572.0648460533673
